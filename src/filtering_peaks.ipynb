# %%
from detector_script import calculate_frequencies
from dynamic_test import *
import numpy as np

# %%
wf_data, rate = sf.read(f"../samples/long_d0_s0.flac")
wf = [x for x in wf_data[:,1]]

# wf = np.ndarray(wf_data.shape[0], )
# bars = calculate_frequencies(wf, binc, lambda e: e >= threshold and e <= cap)

# %%
class FrequencyFunction(PlotterFunction):
    def __init__(self):
        self.binc = 30
        self.data = wf[:len(wf)//3]
        self.threshold = .3
        self.cap = .9

    def domain(self) -> list:
        bars = calculate_frequencies(self.data, self.binc, lambda e: e >= self.threshold and e <= self.cap)
        return [(b.e_min + b.e_max)/2.0 for b in bars]

    def series(self) -> list:
        bars = calculate_frequencies(self.data, self.binc, lambda e: e >= self.threshold and e <= self.cap)
        return [b.freq for b in bars]

    def get_variables(self) -> list:
        return [
            ('threshold', 0.0, 1.0),
            ('cap', 0.0, 1.0),
            ('binc', 1, 100)
        ]

k = Plotter()
k.plot(FrequencyFunction())
# Out:
# ERROR:tornado.application:Uncaught exception GET /2/ws (127.0.0.1)
# HTTPServerRequest(protocol='http', host='127.0.0.1:8988', method='GET', uri='/2/ws', version='HTTP/1.1', remote_ip='127.0.0.1')
# Traceback (most recent call last):
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/tornado/websocket.py", line 631, in _run_callback
#     result = callback(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/backends/backend_webagg.py", line 162, in on_message
#     manager.handle_json(message)
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/backends/backend_webagg_core.py", line 464, in handle_json
#     self.canvas.handle_event(content)
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/backends/backend_webagg_core.py", line 264, in handle_event
#     return handler(event)
#            ^^^^^^^^^^^^^^
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/backends/backend_webagg_core.py", line 303, in _handle_mouse
#     modifiers=modifiers, guiEvent=guiEvent)._process()
#                                             ^^^^^^^^^^
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/backend_bases.py", line 1271, in _process
#     self.canvas.callbacks.process(self.name, self)
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/cbook.py", line 303, in process
#     self.exception_handler(exc)
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/cbook.py", line 87, in _exception_printer
#     raise exc
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/cbook.py", line 298, in process
#     func(*args, **kwargs)
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/widgets.py", line 561, in _update
#     self.set_val(val)
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/widgets.py", line 595, in set_val
#     self._observers.process('changed', val)
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/cbook.py", line 303, in process
#     self.exception_handler(exc)
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/cbook.py", line 87, in _exception_printer
#     raise exc
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/cbook.py", line 298, in process
#     func(*args, **kwargs)
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/widgets.py", line 612, in <lambda>
#     return self._observers.connect('changed', lambda val: func(val))
#                                                           ^^^^^^^^^
#   File "/home/chiara/dev/python/beta_detector/src/dynamic_test.py", line 30, in update
#     self.fig.canvas.draw_idle()
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/backends/backend_webagg_core.py", line 198, in draw_idle
#     self.send_event("draw")
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/backends/backend_webagg_core.py", line 365, in send_event
#     self.manager._send_event(event_type, **kwargs)
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/backends/backend_webagg_core.py", line 511, in _send_event
#     s.send_json(payload)
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/backends/backend_webagg.py", line 165, in send_json
#     self.write_message(json.dumps(content))
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/tornado/websocket.py", line 332, in write_message
#     raise WebSocketClosedError()
# tornado.websocket.WebSocketClosedError
# ERROR:tornado.application:Uncaught exception GET /4/ws (127.0.0.1)
# HTTPServerRequest(protocol='http', host='127.0.0.1:8988', method='GET', uri='/4/ws', version='HTTP/1.1', remote_ip='127.0.0.1')
# Traceback (most recent call last):
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/tornado/websocket.py", line 631, in _run_callback
#     result = callback(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/backends/backend_webagg.py", line 162, in on_message
#     manager.handle_json(message)
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/backends/backend_webagg_core.py", line 464, in handle_json
#     self.canvas.handle_event(content)
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/backends/backend_webagg_core.py", line 264, in handle_event
#     return handler(event)
#            ^^^^^^^^^^^^^^
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/backends/backend_webagg_core.py", line 303, in _handle_mouse
#     modifiers=modifiers, guiEvent=guiEvent)._process()
#                                             ^^^^^^^^^^
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/backend_bases.py", line 1271, in _process
#     self.canvas.callbacks.process(self.name, self)
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/cbook.py", line 303, in process
#     self.exception_handler(exc)
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/cbook.py", line 87, in _exception_printer
#     raise exc
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/cbook.py", line 298, in process
#     func(*args, **kwargs)
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/widgets.py", line 561, in _update
#     self.set_val(val)
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/widgets.py", line 592, in set_val
#     self.ax.figure.canvas.draw_idle()
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/backends/backend_webagg_core.py", line 198, in draw_idle
#     self.send_event("draw")
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/backends/backend_webagg_core.py", line 365, in send_event
#     self.manager._send_event(event_type, **kwargs)
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/backends/backend_webagg_core.py", line 511, in _send_event
#     s.send_json(payload)
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/backends/backend_webagg.py", line 165, in send_json
#     self.write_message(json.dumps(content))
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/tornado/websocket.py", line 332, in write_message
#     raise WebSocketClosedError()
# tornado.websocket.WebSocketClosedError
# ERROR:tornado.application:Uncaught exception GET /5/ws (127.0.0.1)
# HTTPServerRequest(protocol='http', host='127.0.0.1:8988', method='GET', uri='/5/ws', version='HTTP/1.1', remote_ip='127.0.0.1')
# Traceback (most recent call last):
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/tornado/websocket.py", line 631, in _run_callback
#     result = callback(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/backends/backend_webagg.py", line 162, in on_message
#     manager.handle_json(message)
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/backends/backend_webagg_core.py", line 464, in handle_json
#     self.canvas.handle_event(content)
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/backends/backend_webagg_core.py", line 264, in handle_event
#     return handler(event)
#            ^^^^^^^^^^^^^^
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/backends/backend_webagg_core.py", line 303, in _handle_mouse
#     modifiers=modifiers, guiEvent=guiEvent)._process()
#                                             ^^^^^^^^^^
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/backend_bases.py", line 1271, in _process
#     self.canvas.callbacks.process(self.name, self)
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/cbook.py", line 303, in process
#     self.exception_handler(exc)
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/cbook.py", line 87, in _exception_printer
#     raise exc
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/cbook.py", line 298, in process
#     func(*args, **kwargs)
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/backend_bases.py", line 2987, in mouse_move
#     self.set_message(self._mouse_event_to_message(event))
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/backends/backend_webagg_core.py", line 396, in set_message
#     self.canvas.send_event("message", message=message)
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/backends/backend_webagg_core.py", line 365, in send_event
#     self.manager._send_event(event_type, **kwargs)
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/backends/backend_webagg_core.py", line 511, in _send_event
#     s.send_json(payload)
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/matplotlib/backends/backend_webagg.py", line 165, in send_json
#     self.write_message(json.dumps(content))
#   File "/home/chiara/dev/python/beta_detector/lib/python3.11/site-packages/tornado/websocket.py", line 332, in write_message
#     raise WebSocketClosedError()
# tornado.websocket.WebSocketClosedError
